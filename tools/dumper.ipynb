# %%
from safetensors import safe_open

with safe_open("../assets/llama3/model-00001-of-00004.safetensors", framework="pt", device="cpu") as f:
    embed_matrix = f.get_tensor("model.embed_tokens.weight")
    token_id = 100
    embedding = embed_matrix[token_id]
    print(embedding.sum())
# Out:
# tensor(0.4590, dtype=torch.bfloat16)
